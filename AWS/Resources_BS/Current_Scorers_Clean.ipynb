# %%
# Import Numpy
import numpy as np

# Import Matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# SQL ALchemy 
from sqlalchemy import create_engine

# Import PyMySQL
import pymysql
pymysql.install_as_MySQLdb()

# Import Pandas 
import pandas as pd

# %%
# Loading CSV files
csv = "top_20_current_scorers.csv"

# %%
current_season = pd.read_csv(csv)
current_season.head()
# Out:
#         id firstname  lastname pos   birthdate  daysalive    season  seasonid  \
# 0  8466138       Joe  Thornton   C  1979-07-02       6673  19971998         1
# 1  8466138       Joe  Thornton   C  1979-07-02       6676  19971998         1
# 2  8466138       Joe  Thornton   C  1979-07-02       6678  19971998         1
# 3  8466138       Joe  Thornton   C  1979-07-02       6680  19971998         1
# 4  8466138       Joe  Thornton   C  1979-07-02       6682  19971998         1
#
#    gameid  assists  ...  shg  shp  bs  pm  pts           team  \
# 0       1        0  ...    0    0   0   0    0  Boston Bruins
# 1       2        0  ...    0    0   0  -1    0  Boston Bruins
# 2       3        0  ...    0    0   0   0    0  Boston Bruins
# 3       4        0  ...    0    0   0   0    0  Boston Bruins
# 4       5        0  ...    0    0   0   0    0  Boston Bruins
#
#                  opp        date   home    win
# 0    Phoenix Coyotes  1997-10-08  False   True
# ...

# %%
# current = current_season.drop(current_season.loc[current_season['season']==20192020].index, inplace=True)
# current_season.head()

# %%
current = current_season[current_season.season != 20192020]
current
# Out:
#             id firstname  lastname pos   birthdate  daysalive    season  \
# 0      8466138       Joe  Thornton   C  1979-07-02       6673  19971998
# 1      8466138       Joe  Thornton   C  1979-07-02       6676  19971998
# 2      8466138       Joe  Thornton   C  1979-07-02       6678  19971998
# 3      8466138       Joe  Thornton   C  1979-07-02       6680  19971998
# 4      8466138       Joe  Thornton   C  1979-07-02       6682  19971998
# 5      8466138       Joe  Thornton   C  1979-07-02       6683  19971998
# 6      8466138       Joe  Thornton   C  1979-07-02       6686  19971998
# 7      8466138       Joe  Thornton   C  1979-07-02       6690  19971998
# 8      8466138       Joe  Thornton   C  1979-07-02       6695  19971998
# 9      8466138       Joe  Thornton   C  1979-07-02       6697  19971998
# 10     8466138       Joe  Thornton   C  1979-07-02       6702  19971998
# 11     8466138       Joe  Thornton   C  1979-07-02       6704  19971998
# ...

# %%
current.to_csv("top20_current_scorers_cleaner.csv", index=False)
